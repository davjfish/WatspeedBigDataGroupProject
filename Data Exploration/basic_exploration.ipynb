# %% [markdown]
# # Creation of a 911 emergency response db

# %%
import os.path

# first let's load up the dataset
# the unzipped csv is too large for github so teammates will need to unzip it locally before continuing

assert os.path.isfile("911.csv"), "You must unzip the raw data before continuing"

# %%
import pandas as pd

# load the data into a pandas dataframe

df = pd.read_csv("911.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 663522 entries, 0 to 663521
# Data columns (total 9 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   lat        663522 non-null  float64
#  1   lng        663522 non-null  float64
#  2   desc       663522 non-null  object
#  3   zip        583323 non-null  float64
#  4   title      663522 non-null  object
#  5   timeStamp  663522 non-null  object
#  6   twp        663229 non-null  object
#  7   addr       663522 non-null  object
#  8   e          663522 non-null  int64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 45.6+ MB

# %%
# let's take a look at the first few rows'
df.head()
# Out:
#          lat        lng                                               desc  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1  40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2  40.121182 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3  40.116153 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 4  40.251492 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
#
#        zip                    title            timeStamp                twp  \
# 0  19525.0   EMS: BACK PAINS/INJURY  2015-12-10 17:10:52        NEW HANOVER
# 1  19446.0  EMS: DIABETIC EMERGENCY  2015-12-10 17:29:21  HATFIELD TOWNSHIP
# 2  19401.0      Fire: GAS-ODOR/LEAK  2015-12-10 14:39:21         NORRISTOWN
# 3  19401.0   EMS: CARDIAC EMERGENCY  2015-12-10 16:47:36         NORRISTOWN
# 4      NaN           EMS: DIZZINESS  2015-12-10 16:56:52   LOWER POTTSGROVE
#
#                          addr  e
# 0      REINDEER CT & DEAD END  1
# 1  BRIAR PATH & WHITEMARSH LN  1
# 2                    HAWS AVE  1
# 3          AIRY ST & SWEDE ST  1
# 4    CHERRYWOOD CT & DEAD END  1

# %%
df["e"].value_counts()
# Out:
# e
# 1    663522
# Name: count, dtype: int64

# %%
# I want to develop some more nuance in the title column.
# perhaps can split on the colon (:) to determine the category of call

def get_type(title):
    return title.split(":")[0].strip()


df["type"] = df["title"].apply(get_type)
df["type"].value_counts()
# Out:
# type
# EMS        332692
# Traffic    230208
# Fire       100622
# Name: count, dtype: int64

# %%
# now let's clean the title up (i.e., remove the category)

def clean_title(title):
    txt = title.split(":")[-1].strip()
    if txt[-1] == "-":
        txt = txt[:-1].strip()
    return txt


df["clean_title"] = df["title"].apply(clean_title)
df["clean_title"].value_counts()
# Out:
# clean_title
# VEHICLE ACCIDENT         184749
# DISABLED VEHICLE          47917
# FIRE ALARM                38452
# FALL VICTIM               34683
# RESPIRATORY EMERGENCY     34250
#                           ...
# SUICIDE ATTEMPT               2
# HIT + RUN                     1
# PRISONER IN CUSTODY           1
# ANIMAL COMPLAINT              1
# FOOT PATROL                   1
# Name: count, Length: 88, dtype: int64

# %%
# what's going on with the "RESCUE" titles?

mask = df["title"].str.contains("RESCUE")
df.loc[mask, :]
# Out:
#               lat        lng  \
# 354     40.216190 -75.238794
# 356     40.216190 -75.238794
# 523     40.089604 -75.148337
# 524     40.089604 -75.148337
# 579     40.182048 -75.481795
# ...           ...        ...
# 660126  40.250806 -75.682868
# 660586  40.121497 -75.339905
# 660587  40.121497 -75.339905
# 662058  40.375774 -75.487864
# 662059  40.376552 -75.485783
#
#                                                      desc      zip  \
# 354     ARBOUR GREEN CIR & CLOVER LEAF LN; MONTGOMERY;...  18936.0
# 356     ARBOUR GREEN CIR & CLOVER LEAF LN;  MONTGOMERY...  18936.0
# 523     BARKER RD & GREENWOOD AVE;  CHELTENHAM; Statio...  19095.0
# 524     BARKER RD & GREENWOOD AVE; CHELTENHAM; 2015-12...  19095.0
# 579     HOPWOOD RD & LONGACRE DR; UPPER PROVIDENCE; 20...  19426.0
# ...                                                   ...      ...
# 660126  FAIRVIEW ST & JEFFERSON ST; WEST POTTSGROVE; 2...  19464.0
# 660586  WALNUT ST & DEAD END;  NORRISTOWN; Station 308...      NaN
# 660587  WALNUT ST & DEAD END; NORRISTOWN; 2020-07-21 @...      NaN
# 662058  WALNUT ST & W 6TH ST;  RED HILL; Station 369; ...  18076.0
# 662059  WALNUT ST & W 6TH ST; RED HILL; 2020-07-25 @ 0...      NaN
#
#                           title            timeStamp               twp  \
# 354      Fire: RESCUE - GENERAL  2015-12-11 16:32:13        MONTGOMERY
# 356       EMS: RESCUE - GENERAL  2015-12-11 16:32:27        MONTGOMERY
# 523       EMS: RESCUE - GENERAL  2015-12-12 03:03:57        CHELTENHAM
# 524      Fire: RESCUE - GENERAL  2015-12-12 03:03:46        CHELTENHAM
# 579     Fire: RESCUE - ELEVATOR  2015-12-12 09:44:56  UPPER PROVIDENCE
# ...                         ...                  ...               ...
# 660126   Fire: RESCUE - GENERAL  2020-07-19 22:46:44   WEST POTTSGROVE
# 660586    EMS: RESCUE - GENERAL  2020-07-21 11:59:54        NORRISTOWN
# 660587   Fire: RESCUE - GENERAL  2020-07-21 11:59:49        NORRISTOWN
# 662058    EMS: RESCUE - GENERAL  2020-07-25 08:48:52          RED HILL
# 662059   Fire: RESCUE - GENERAL  2020-07-25 08:48:39          RED HILL
#
#                                      addr  e  type        clean_title
# 354     ARBOUR GREEN CIR & CLOVER LEAF LN  1  Fire   RESCUE - GENERAL
# 356     ARBOUR GREEN CIR & CLOVER LEAF LN  1   EMS   RESCUE - GENERAL
# 523             BARKER RD & GREENWOOD AVE  1   EMS   RESCUE - GENERAL
# 524             BARKER RD & GREENWOOD AVE  1  Fire   RESCUE - GENERAL
# 579              HOPWOOD RD & LONGACRE DR  1  Fire  RESCUE - ELEVATOR
# ...                                   ... ..   ...                ...
# 660126         FAIRVIEW ST & JEFFERSON ST  1  Fire   RESCUE - GENERAL
# 660586               WALNUT ST & DEAD END  1   EMS   RESCUE - GENERAL
# 660587               WALNUT ST & DEAD END  1  Fire   RESCUE - GENERAL
# 662058               WALNUT ST & W 6TH ST  1   EMS   RESCUE - GENERAL
# 662059               WALNUT ST & W 6TH ST  1  Fire   RESCUE - GENERAL
#
# [2117 rows x 11 columns]

# %%
import numpy as np


# also, I want to clean up the zip column. It should be an int

def to_int(x):
    try:
        return int(x)
    except:
        return np.nan


df["zip"] = df["zip"].apply(to_int)
df["zip"]
# Out:
# 0         19525.0
# 1         19446.0
# 2         19401.0
# 3         19401.0
# 4             NaN
#            ...
# 663517    19403.0
# 663518    19403.0
# 663519    19041.0
# 663520    19401.0
# 663521    19041.0
# Name: zip, Length: 663522, dtype: float64

# %%
df.head()
# Out:
#          lat        lng                                               desc  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1  40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2  40.121182 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3  40.116153 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 4  40.251492 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
#
#        zip                    title            timeStamp                twp  \
# 0  19525.0   EMS: BACK PAINS/INJURY  2015-12-10 17:10:52        NEW HANOVER
# 1  19446.0  EMS: DIABETIC EMERGENCY  2015-12-10 17:29:21  HATFIELD TOWNSHIP
# 2  19401.0      Fire: GAS-ODOR/LEAK  2015-12-10 14:39:21         NORRISTOWN
# 3  19401.0   EMS: CARDIAC EMERGENCY  2015-12-10 16:47:36         NORRISTOWN
# 4      NaN           EMS: DIZZINESS  2015-12-10 16:56:52   LOWER POTTSGROVE
#
#                          addr  e  type         clean_title
# 0      REINDEER CT & DEAD END  1   EMS   BACK PAINS/INJURY
# 1  BRIAR PATH & WHITEMARSH LN  1   EMS  DIABETIC EMERGENCY
# 2                    HAWS AVE  1  Fire       GAS-ODOR/LEAK
# 3          AIRY ST & SWEDE ST  1   EMS   CARDIAC EMERGENCY
# 4    CHERRYWOOD CT & DEAD END  1   EMS           DIZZINESS

# %%
import re

# %%
item = "station av"
x = re.search(r'\bstation\b\s[\bave\b|"cr"]', item)
print(x)
# Out:
# <re.Match object; span=(0, 9), match='station a'>

# %%
import os

import pandas as pd

os.chdir("../application")

os.environ["DJANGO_SETTINGS_MODULE"] = "ERDash.settings"
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

import django

django.setup()

from dashboard import models

# %%
# first create administrative areas
areas = df.loc[:, ["zip", "twp"]].value_counts()

create_list = list()
for zip_code, name in areas.index:
    name = name.upper()
    try:
        zip_code = int(zip_code)
    except:
        zip_code = None
    area = models.AdministrativeArea( name=name)

    create_list.append(area)


models.AdministrativeArea.objects.bulk_create(create_list[:])
# Out:
# [<AdministrativeArea: AdministrativeArea object (2236)>,
#  <AdministrativeArea: AdministrativeArea object (2237)>,
#  <AdministrativeArea: AdministrativeArea object (2238)>,
#  <AdministrativeArea: AdministrativeArea object (2239)>,
#  <AdministrativeArea: AdministrativeArea object (2240)>,
#  <AdministrativeArea: AdministrativeArea object (2241)>,
#  <AdministrativeArea: AdministrativeArea object (2242)>,
#  <AdministrativeArea: AdministrativeArea object (2243)>,
#  <AdministrativeArea: AdministrativeArea object (2244)>,
#  <AdministrativeArea: AdministrativeArea object (2245)>,
#  <AdministrativeArea: AdministrativeArea object (2246)>,
#  <AdministrativeArea: AdministrativeArea object (2247)>,
#  <AdministrativeArea: AdministrativeArea object (2248)>,
#  <AdministrativeArea: AdministrativeArea object (2249)>,
#  <AdministrativeArea: AdministrativeArea object (2250)>,
#  <AdministrativeArea: AdministrativeArea object (2251)>,
#  <AdministrativeArea: AdministrativeArea object (2252)>,
#  <AdministrativeArea: AdministrativeArea object (2253)>,
#  <AdministrativeArea: AdministrativeArea object (2254)>,
#  <AdministrativeArea: AdministrativeArea object (2255)>,
#  <AdministrativeArea: AdministrativeArea object (2256)>,
#  <AdministrativeArea: AdministrativeArea object (2257)>,
#  <AdministrativeArea: AdministrativeArea object (2258)>,
#  <AdministrativeArea: AdministrativeArea object (2259)>,
#  <AdministrativeArea: AdministrativeArea object (2260)>,
#  <AdministrativeArea: AdministrativeArea object (2261)>,
#  <AdministrativeArea: AdministrativeArea object (2262)>,
#  <AdministrativeArea: AdministrativeArea object (2263)>,
#  <AdministrativeArea: AdministrativeArea object (2264)>,
#  <AdministrativeArea: AdministrativeArea object (2265)>,
#  <AdministrativeArea: AdministrativeArea object (2266)>,
#  <AdministrativeArea: AdministrativeArea object (2267)>,
#  <AdministrativeArea: AdministrativeArea object (2268)>,
#  <AdministrativeArea: AdministrativeArea object (2269)>,
#  <AdministrativeArea: AdministrativeArea object (2270)>,
#  <AdministrativeArea: AdministrativeArea object (2271)>,
#  <AdministrativeArea: AdministrativeArea object (2272)>,
#  <AdministrativeArea: AdministrativeArea object (2273)>,
#  <AdministrativeArea: AdministrativeArea object (2274)>,
#  <AdministrativeArea: AdministrativeArea object (2275)>,
#  <AdministrativeArea: AdministrativeArea object (2276)>,
#  <AdministrativeArea: AdministrativeArea object (2277)>,
#  <AdministrativeArea: AdministrativeArea object (2278)>,
#  <AdministrativeArea: AdministrativeArea object (2279)>,
#  <AdministrativeArea: AdministrativeArea object (2280)>,
#  <AdministrativeArea: AdministrativeArea object (2281)>,
#  <AdministrativeArea: AdministrativeArea object (2282)>,
#  <AdministrativeArea: AdministrativeArea object (2283)>,
#  <AdministrativeArea: AdministrativeArea object (2284)>,
#  <AdministrativeArea: AdministrativeArea object (2285)>,
#  <AdministrativeArea: AdministrativeArea object (2286)>,
#  <AdministrativeArea: AdministrativeArea object (2287)>,
#  <AdministrativeArea: AdministrativeArea object (2288)>,
#  <AdministrativeArea: AdministrativeArea object (2289)>,
#  <AdministrativeArea: AdministrativeArea object (2290)>,
#  <AdministrativeArea: AdministrativeArea object (2291)>,
#  <AdministrativeArea: AdministrativeArea object (2292)>,
#  <AdministrativeArea: AdministrativeArea object (2293)>,
#  <AdministrativeArea: AdministrativeArea object (2294)>,
#  <AdministrativeArea: AdministrativeArea object (2295)>,
#  <AdministrativeArea: AdministrativeArea object (2296)>,
#  <AdministrativeArea: AdministrativeArea object (2297)>,
#  <AdministrativeArea: AdministrativeArea object (2298)>,
#  <AdministrativeArea: AdministrativeArea object (2299)>,
#  <AdministrativeArea: AdministrativeArea object (2300)>,
#  <AdministrativeArea: AdministrativeArea object (2301)>,
#  <AdministrativeArea: AdministrativeArea object (2302)>,
#  <AdministrativeArea: AdministrativeArea object (2303)>,
#  <AdministrativeArea: AdministrativeArea object (2304)>,
#  <AdministrativeArea: AdministrativeArea object (2305)>,
#  <AdministrativeArea: AdministrativeArea object (2306)>,
#  <AdministrativeArea: AdministrativeArea object (2307)>,
#  <AdministrativeArea: AdministrativeArea object (2308)>,
#  <AdministrativeArea: AdministrativeArea object (2309)>,
#  <AdministrativeArea: AdministrativeArea object (2310)>,
#  <AdministrativeArea: AdministrativeArea object (2311)>,
#  <AdministrativeArea: AdministrativeArea object (2312)>,
#  <AdministrativeArea: AdministrativeArea object (2313)>,
#  <AdministrativeArea: AdministrativeArea object (2314)>,
#  <AdministrativeArea: AdministrativeArea object (2315)>,
#  <AdministrativeArea: AdministrativeArea object (2316)>,
#  <AdministrativeArea: AdministrativeArea object (2317)>,
#  <AdministrativeArea: AdministrativeArea object (2318)>,
#  <AdministrativeArea: AdministrativeArea object (2319)>,
#  <AdministrativeArea: AdministrativeArea object (2320)>,
#  <AdministrativeArea: AdministrativeArea object (2321)>,
#  <AdministrativeArea: AdministrativeArea object (2322)>,
#  <AdministrativeArea: AdministrativeArea object (2323)>,
#  <AdministrativeArea: AdministrativeArea object (2324)>,
#  <AdministrativeArea: AdministrativeArea object (2325)>,
#  <AdministrativeArea: AdministrativeArea object (2326)>,
#  <AdministrativeArea: AdministrativeArea object (2327)>,
#  <AdministrativeArea: AdministrativeArea object (2328)>,
#  <AdministrativeArea: AdministrativeArea object (2329)>,
#  <AdministrativeArea: AdministrativeArea object (2330)>,
#  <AdministrativeArea: AdministrativeArea object (2331)>,
#  <AdministrativeArea: AdministrativeArea object (2332)>,
#  <AdministrativeArea: AdministrativeArea object (2333)>,
#  <AdministrativeArea: AdministrativeArea object (2334)>,
#  <AdministrativeArea: AdministrativeArea object (2335)>,
#  <AdministrativeArea: AdministrativeArea object (2336)>,
#  <AdministrativeArea: AdministrativeArea object (2337)>,
#  <AdministrativeArea: AdministrativeArea object (2338)>,
#  <AdministrativeArea: AdministrativeArea object (2339)>,
#  <AdministrativeArea: AdministrativeArea object (2340)>,
#  <AdministrativeArea: AdministrativeArea object (2341)>,
#  <AdministrativeArea: AdministrativeArea object (2342)>,
#  <AdministrativeArea: AdministrativeArea object (2343)>,
#  <AdministrativeArea: AdministrativeArea object (2344)>,
#  <AdministrativeArea: AdministrativeArea object (2345)>,
#  <AdministrativeArea: AdministrativeArea object (2346)>,
#  <AdministrativeArea: AdministrativeArea object (2347)>,
#  <AdministrativeArea: AdministrativeArea object (2348)>,
#  <AdministrativeArea: AdministrativeArea object (2349)>,
#  <AdministrativeArea: AdministrativeArea object (2350)>,
#  <AdministrativeArea: AdministrativeArea object (2351)>,
#  <AdministrativeArea: AdministrativeArea object (2352)>,
#  <AdministrativeArea: AdministrativeArea object (2353)>,
#  <AdministrativeArea: AdministrativeArea object (2354)>,
#  <AdministrativeArea: AdministrativeArea object (2355)>,
#  <AdministrativeArea: AdministrativeArea object (2356)>,
#  <AdministrativeArea: AdministrativeArea object (2357)>,
#  <AdministrativeArea: AdministrativeArea object (2358)>,
#  <AdministrativeArea: AdministrativeArea object (2359)>,
#  <AdministrativeArea: AdministrativeArea object (2360)>,
#  <AdministrativeArea: AdministrativeArea object (2361)>,
#  <AdministrativeArea: AdministrativeArea object (2362)>,
#  <AdministrativeArea: AdministrativeArea object (2363)>,
#  <AdministrativeArea: AdministrativeArea object (2364)>,
#  <AdministrativeArea: AdministrativeArea object (2365)>,
#  <AdministrativeArea: AdministrativeArea object (2366)>,
#  <AdministrativeArea: AdministrativeArea object (2367)>,
#  <AdministrativeArea: AdministrativeArea object (2368)>,
#  <AdministrativeArea: AdministrativeArea object (2369)>,
#  <AdministrativeArea: AdministrativeArea object (2370)>,
#  <AdministrativeArea: AdministrativeArea object (2371)>,
#  <AdministrativeArea: AdministrativeArea object (2372)>,
#  <AdministrativeArea: AdministrativeArea object (2373)>,
#  <AdministrativeArea: AdministrativeArea object (2374)>,
#  <AdministrativeArea: AdministrativeArea object (2375)>,
#  <AdministrativeArea: AdministrativeArea object (2376)>,
#  <AdministrativeArea: AdministrativeArea object (2377)>,
#  <AdministrativeArea: AdministrativeArea object (2378)>,
#  <AdministrativeArea: AdministrativeArea object (2379)>,
#  <AdministrativeArea: AdministrativeArea object (2380)>,
#  <AdministrativeArea: AdministrativeArea object (2381)>,
#  <AdministrativeArea: AdministrativeArea object (2382)>,
#  <AdministrativeArea: AdministrativeArea object (2383)>,
#  <AdministrativeArea: AdministrativeArea object (2384)>,
#  <AdministrativeArea: AdministrativeArea object (2385)>,
#  <AdministrativeArea: AdministrativeArea object (2386)>,
#  <AdministrativeArea: AdministrativeArea object (2387)>,
#  <AdministrativeArea: AdministrativeArea object (2388)>,
#  <AdministrativeArea: AdministrativeArea object (2389)>,
#  <AdministrativeArea: AdministrativeArea object (2390)>,
#  <AdministrativeArea: AdministrativeArea object (2391)>,
#  <AdministrativeArea: AdministrativeArea object (2392)>,
#  <AdministrativeArea: AdministrativeArea object (2393)>,
#  <AdministrativeArea: AdministrativeArea object (2394)>,
#  <AdministrativeArea: AdministrativeArea object (2395)>,
#  <AdministrativeArea: AdministrativeArea object (2396)>,
#  <AdministrativeArea: AdministrativeArea object (2397)>,
#  <AdministrativeArea: AdministrativeArea object (2398)>,
#  <AdministrativeArea: AdministrativeArea object (2399)>,
#  <AdministrativeArea: AdministrativeArea object (2400)>,
#  <AdministrativeArea: AdministrativeArea object (2401)>,
#  <AdministrativeArea: AdministrativeArea object (2402)>,
#  <AdministrativeArea: AdministrativeArea object (2403)>,
#  <AdministrativeArea: AdministrativeArea object (2404)>,
#  <AdministrativeArea: AdministrativeArea object (2405)>,
#  <AdministrativeArea: AdministrativeArea object (2406)>,
#  <AdministrativeArea: AdministrativeArea object (2407)>,
#  <AdministrativeArea: AdministrativeArea object (2408)>,
#  <AdministrativeArea: AdministrativeArea object (2409)>,
#  <AdministrativeArea: AdministrativeArea object (2410)>,
#  <AdministrativeArea: AdministrativeArea object (2411)>,
#  <AdministrativeArea: AdministrativeArea object (2412)>,
#  <AdministrativeArea: AdministrativeArea object (2413)>,
#  <AdministrativeArea: AdministrativeArea object (2414)>,
#  <AdministrativeArea: AdministrativeArea object (2415)>,
#  <AdministrativeArea: AdministrativeArea object (2416)>,
#  <AdministrativeArea: AdministrativeArea object (2417)>,
#  <AdministrativeArea: AdministrativeArea object (2418)>,
#  <AdministrativeArea: AdministrativeArea object (2419)>,
#  <AdministrativeArea: AdministrativeArea object (2420)>,
#  <AdministrativeArea: AdministrativeArea object (2421)>,
#  <AdministrativeArea: AdministrativeArea object (2422)>,
#  <AdministrativeArea: AdministrativeArea object (2423)>,
#  <AdministrativeArea: AdministrativeArea object (2424)>,
#  <AdministrativeArea: AdministrativeArea object (2425)>,
#  <AdministrativeArea: AdministrativeArea object (2426)>,
#  <AdministrativeArea: AdministrativeArea object (2427)>,
#  <AdministrativeArea: AdministrativeArea object (2428)>,
#  <AdministrativeArea: AdministrativeArea object (2429)>,
#  <AdministrativeArea: AdministrativeArea object (2430)>,
#  <AdministrativeArea: AdministrativeArea object (2431)>,
#  <AdministrativeArea: AdministrativeArea object (2432)>,
#  <AdministrativeArea: AdministrativeArea object (2433)>,
#  <AdministrativeArea: AdministrativeArea object (2434)>,
#  <AdministrativeArea: AdministrativeArea object (2435)>,
#  <AdministrativeArea: AdministrativeArea object (2436)>,
#  <AdministrativeArea: AdministrativeArea object (2437)>,
#  <AdministrativeArea: AdministrativeArea object (2438)>,
#  <AdministrativeArea: AdministrativeArea object (2439)>,
#  <AdministrativeArea: AdministrativeArea object (2440)>,
#  <AdministrativeArea: AdministrativeArea object (2441)>,
#  <AdministrativeArea: AdministrativeArea object (2442)>,
#  <AdministrativeArea: AdministrativeArea object (2443)>,
#  <AdministrativeArea: AdministrativeArea object (2444)>,
#  <AdministrativeArea: AdministrativeArea object (2445)>,
#  <AdministrativeArea: AdministrativeArea object (2446)>,
#  <AdministrativeArea: AdministrativeArea object (2447)>,
#  <AdministrativeArea: AdministrativeArea object (2448)>,
#  <AdministrativeArea: AdministrativeArea object (2449)>,
#  <AdministrativeArea: AdministrativeArea object (2450)>,
#  <AdministrativeArea: AdministrativeArea object (2451)>,
#  <AdministrativeArea: AdministrativeArea object (2452)>,
#  <AdministrativeArea: AdministrativeArea object (2453)>,
#  <AdministrativeArea: AdministrativeArea object (2454)>,
#  <AdministrativeArea: AdministrativeArea object (2455)>,
#  <AdministrativeArea: AdministrativeArea object (2456)>,
#  <AdministrativeArea: AdministrativeArea object (2457)>,
#  <AdministrativeArea: AdministrativeArea object (2458)>,
#  <AdministrativeArea: AdministrativeArea object (2459)>,
#  <AdministrativeArea: AdministrativeArea object (2460)>,
#  <AdministrativeArea: AdministrativeArea object (2461)>,
#  <AdministrativeArea: AdministrativeArea object (2462)>,
#  <AdministrativeArea: AdministrativeArea object (2463)>,
#  <AdministrativeArea: AdministrativeArea object (2464)>,
#  <AdministrativeArea: AdministrativeArea object (2465)>,
#  <AdministrativeArea: AdministrativeArea object (2466)>,
#  <AdministrativeArea: AdministrativeArea object (2467)>,
#  <AdministrativeArea: AdministrativeArea object (2468)>,
#  <AdministrativeArea: AdministrativeArea object (2469)>,
#  <AdministrativeArea: AdministrativeArea object (2470)>,
#  <AdministrativeArea: AdministrativeArea object (2471)>,
#  <AdministrativeArea: AdministrativeArea object (2472)>,
#  <AdministrativeArea: AdministrativeArea object (2473)>,
#  <AdministrativeArea: AdministrativeArea object (2474)>,
#  <AdministrativeArea: AdministrativeArea object (2475)>,
#  <AdministrativeArea: AdministrativeArea object (2476)>,
#  <AdministrativeArea: AdministrativeArea object (2477)>,
#  <AdministrativeArea: AdministrativeArea object (2478)>,
#  <AdministrativeArea: AdministrativeArea object (2479)>,
#  <AdministrativeArea: AdministrativeArea object (2480)>,
#  <AdministrativeArea: AdministrativeArea object (2481)>,
#  <AdministrativeArea: AdministrativeArea object (2482)>,
#  <AdministrativeArea: AdministrativeArea object (2483)>,
#  <AdministrativeArea: AdministrativeArea object (2484)>,
#  <AdministrativeArea: AdministrativeArea object (2485)>,
#  <AdministrativeArea: AdministrativeArea object (2486)>,
#  <AdministrativeArea: AdministrativeArea object (2487)>,
#  <AdministrativeArea: AdministrativeArea object (2488)>,
#  <AdministrativeArea: AdministrativeArea object (2489)>,
#  <AdministrativeArea: AdministrativeArea object (2490)>,
#  <AdministrativeArea: AdministrativeArea object (2491)>,
#  <AdministrativeArea: AdministrativeArea object (2492)>,
#  <AdministrativeArea: AdministrativeArea object (2493)>,
#  <AdministrativeArea: AdministrativeArea object (2494)>,
#  <AdministrativeArea: AdministrativeArea object (2495)>,
#  <AdministrativeArea: AdministrativeArea object (2496)>,
#  <AdministrativeArea: AdministrativeArea object (2497)>,
#  <AdministrativeArea: AdministrativeArea object (2498)>,
#  <AdministrativeArea: AdministrativeArea object (2499)>,
#  <AdministrativeArea: AdministrativeArea object (2500)>,
#  <AdministrativeArea: AdministrativeArea object (2501)>,
#  <AdministrativeArea: AdministrativeArea object (2502)>,
#  <AdministrativeArea: AdministrativeArea object (2503)>,
#  <AdministrativeArea: AdministrativeArea object (2504)>,
#  <AdministrativeArea: AdministrativeArea object (2505)>,
#  <AdministrativeArea: AdministrativeArea object (2506)>,
#  <AdministrativeArea: AdministrativeArea object (2507)>,
#  <AdministrativeArea: AdministrativeArea object (2508)>,
#  <AdministrativeArea: AdministrativeArea object (2509)>,
#  <AdministrativeArea: AdministrativeArea object (2510)>,
#  <AdministrativeArea: AdministrativeArea object (2511)>,
#  <AdministrativeArea: AdministrativeArea object (2512)>,
#  <AdministrativeArea: AdministrativeArea object (2513)>,
#  <AdministrativeArea: AdministrativeArea object (2514)>,
#  <AdministrativeArea: AdministrativeArea object (2515)>,
#  <AdministrativeArea: AdministrativeArea object (2516)>,
#  <AdministrativeArea: AdministrativeArea object (2517)>,
#  <AdministrativeArea: AdministrativeArea object (2518)>,
#  <AdministrativeArea: AdministrativeArea object (2519)>,
#  <AdministrativeArea: AdministrativeArea object (2520)>,
#  <AdministrativeArea: AdministrativeArea object (2521)>,
#  <AdministrativeArea: AdministrativeArea object (2522)>,
#  <AdministrativeArea: AdministrativeArea object (2523)>,
#  <AdministrativeArea: AdministrativeArea object (2524)>,
#  <AdministrativeArea: AdministrativeArea object (2525)>,
#  <AdministrativeArea: AdministrativeArea object (2526)>,
#  <AdministrativeArea: AdministrativeArea object (2527)>,
#  <AdministrativeArea: AdministrativeArea object (2528)>,
#  <AdministrativeArea: AdministrativeArea object (2529)>,
#  <AdministrativeArea: AdministrativeArea object (2530)>,
#  <AdministrativeArea: AdministrativeArea object (2531)>,
#  <AdministrativeArea: AdministrativeArea object (2532)>,
#  <AdministrativeArea: AdministrativeArea object (2533)>,
#  <AdministrativeArea: AdministrativeArea object (2534)>,
#  <AdministrativeArea: AdministrativeArea object (2535)>,
#  <AdministrativeArea: AdministrativeArea object (2536)>,
#  <AdministrativeArea: AdministrativeArea object (2537)>,
#  <AdministrativeArea: AdministrativeArea object (2538)>,
#  <AdministrativeArea: AdministrativeArea object (2539)>,
#  <AdministrativeArea: AdministrativeArea object (2540)>,
#  <AdministrativeArea: AdministrativeArea object (2541)>,
#  <AdministrativeArea: AdministrativeArea object (2542)>,
#  <AdministrativeArea: AdministrativeArea object (2543)>,
#  <AdministrativeArea: AdministrativeArea object (2544)>,
#  <AdministrativeArea: AdministrativeArea object (2545)>,
#  <AdministrativeArea: AdministrativeArea object (2546)>,
#  <AdministrativeArea: AdministrativeArea object (2547)>,
#  <AdministrativeArea: AdministrativeArea object (2548)>,
#  <AdministrativeArea: AdministrativeArea object (2549)>,
#  <AdministrativeArea: AdministrativeArea object (2550)>,
#  <AdministrativeArea: AdministrativeArea object (2551)>,
#  <AdministrativeArea: AdministrativeArea object (2552)>,
#  <AdministrativeArea: AdministrativeArea object (2553)>,
#  <AdministrativeArea: AdministrativeArea object (2554)>,
#  <AdministrativeArea: AdministrativeArea object (2555)>,
#  <AdministrativeArea: AdministrativeArea object (2556)>,
#  <AdministrativeArea: AdministrativeArea object (2557)>,
#  <AdministrativeArea: AdministrativeArea object (2558)>,
#  <AdministrativeArea: AdministrativeArea object (2559)>,
#  <AdministrativeArea: AdministrativeArea object (2560)>,
#  <AdministrativeArea: AdministrativeArea object (2561)>,
#  <AdministrativeArea: AdministrativeArea object (2562)>,
#  <AdministrativeArea: AdministrativeArea object (2563)>,
#  <AdministrativeArea: AdministrativeArea object (2564)>,
#  <AdministrativeArea: AdministrativeArea object (2565)>,
#  <AdministrativeArea: AdministrativeArea object (2566)>,
#  <AdministrativeArea: AdministrativeArea object (2567)>,
#  <AdministrativeArea: AdministrativeArea object (2568)>,
#  <AdministrativeArea: AdministrativeArea object (2569)>,
#  <AdministrativeArea: AdministrativeArea object (2570)>,
#  <AdministrativeArea: AdministrativeArea object (2571)>,
#  <AdministrativeArea: AdministrativeArea object (2572)>,
#  <AdministrativeArea: AdministrativeArea object (2573)>,
#  <AdministrativeArea: AdministrativeArea object (2574)>,
#  <AdministrativeArea: AdministrativeArea object (2575)>,
#  <AdministrativeArea: AdministrativeArea object (2576)>,
#  <AdministrativeArea: AdministrativeArea object (2577)>,
#  <AdministrativeArea: AdministrativeArea object (2578)>,
#  <AdministrativeArea: AdministrativeArea object (2579)>,
#  <AdministrativeArea: AdministrativeArea object (2580)>,
#  <AdministrativeArea: AdministrativeArea object (2581)>,
#  <AdministrativeArea: AdministrativeArea object (2582)>,
#  <AdministrativeArea: AdministrativeArea object (2583)>,
#  <AdministrativeArea: AdministrativeArea object (2584)>,
#  <AdministrativeArea: AdministrativeArea object (2585)>,
#  <AdministrativeArea: AdministrativeArea object (2586)>,
#  <AdministrativeArea: AdministrativeArea object (2587)>,
#  <AdministrativeArea: AdministrativeArea object (2588)>,
#  <AdministrativeArea: AdministrativeArea object (2589)>,
#  <AdministrativeArea: AdministrativeArea object (2590)>,
#  <AdministrativeArea: AdministrativeArea object (2591)>,
#  <AdministrativeArea: AdministrativeArea object (2592)>,
#  <AdministrativeArea: AdministrativeArea object (2593)>,
#  <AdministrativeArea: AdministrativeArea object (2594)>,
#  <AdministrativeArea: AdministrativeArea object (2595)>,
#  <AdministrativeArea: AdministrativeArea object (2596)>,
#  <AdministrativeArea: AdministrativeArea object (2597)>,
#  <AdministrativeArea: AdministrativeArea object (2598)>,
#  <AdministrativeArea: AdministrativeArea object (2599)>,
#  <AdministrativeArea: AdministrativeArea object (2600)>,
#  <AdministrativeArea: AdministrativeArea object (2601)>,
#  <AdministrativeArea: AdministrativeArea object (2602)>,
#  <AdministrativeArea: AdministrativeArea object (2603)>,
#  <AdministrativeArea: AdministrativeArea object (2604)>,
#  <AdministrativeArea: AdministrativeArea object (2605)>,
#  <AdministrativeArea: AdministrativeArea object (2606)>,
#  <AdministrativeArea: AdministrativeArea object (2607)>,
#  <AdministrativeArea: AdministrativeArea object (2608)>,
#  <AdministrativeArea: AdministrativeArea object (2609)>,
#  <AdministrativeArea: AdministrativeArea object (2610)>,
#  <AdministrativeArea: AdministrativeArea object (2611)>,
#  <AdministrativeArea: AdministrativeArea object (2612)>,
#  <AdministrativeArea: AdministrativeArea object (2613)>,
#  <AdministrativeArea: AdministrativeArea object (2614)>,
#  <AdministrativeArea: AdministrativeArea object (2615)>,
#  <AdministrativeArea: AdministrativeArea object (2616)>,
#  <AdministrativeArea: AdministrativeArea object (2617)>,
#  <AdministrativeArea: AdministrativeArea object (2618)>,
#  <AdministrativeArea: AdministrativeArea object (2619)>,
#  <AdministrativeArea: AdministrativeArea object (2620)>,
#  <AdministrativeArea: AdministrativeArea object (2621)>,
#  <AdministrativeArea: AdministrativeArea object (2622)>,
#  <AdministrativeArea: AdministrativeArea object (2623)>,
#  <AdministrativeArea: AdministrativeArea object (2624)>,
#  <AdministrativeArea: AdministrativeArea object (2625)>,
#  <AdministrativeArea: AdministrativeArea object (2626)>,
#  <AdministrativeArea: AdministrativeArea object (2627)>,
#  <AdministrativeArea: AdministrativeArea object (2628)>,
#  <AdministrativeArea: AdministrativeArea object (2629)>,
#  <AdministrativeArea: AdministrativeArea object (2630)>,
#  <AdministrativeArea: AdministrativeArea object (2631)>,
#  <AdministrativeArea: AdministrativeArea object (2632)>,
#  <AdministrativeArea: AdministrativeArea object (2633)>,
#  <AdministrativeArea: AdministrativeArea object (2634)>,
#  <AdministrativeArea: AdministrativeArea object (2635)>,
#  <AdministrativeArea: AdministrativeArea object (2636)>,
#  <AdministrativeArea: AdministrativeArea object (2637)>,
#  <AdministrativeArea: AdministrativeArea object (2638)>,
#  <AdministrativeArea: AdministrativeArea object (2639)>,
#  <AdministrativeArea: AdministrativeArea object (2640)>,
#  <AdministrativeArea: AdministrativeArea object (2641)>,
#  <AdministrativeArea: AdministrativeArea object (2642)>,
#  <AdministrativeArea: AdministrativeArea object (2643)>,
#  <AdministrativeArea: AdministrativeArea object (2644)>,
#  <AdministrativeArea: AdministrativeArea object (2645)>,
#  <AdministrativeArea: AdministrativeArea object (2646)>,
#  <AdministrativeArea: AdministrativeArea object (2647)>,
#  <AdministrativeArea: AdministrativeArea object (2648)>,
#  <AdministrativeArea: AdministrativeArea object (2649)>,
#  <AdministrativeArea: AdministrativeArea object (2650)>,
#  <AdministrativeArea: AdministrativeArea object (2651)>,
#  <AdministrativeArea: AdministrativeArea object (2652)>,
#  <AdministrativeArea: AdministrativeArea object (2653)>,
#  <AdministrativeArea: AdministrativeArea object (2654)>,
#  <AdministrativeArea: AdministrativeArea object (2655)>,
#  <AdministrativeArea: AdministrativeArea object (2656)>,
#  <AdministrativeArea: AdministrativeArea object (2657)>,
#  <AdministrativeArea: AdministrativeArea object (2658)>,
#  <AdministrativeArea: AdministrativeArea object (2659)>,
#  <AdministrativeArea: AdministrativeArea object (2660)>,
#  <AdministrativeArea: AdministrativeArea object (2661)>,
#  <AdministrativeArea: AdministrativeArea object (2662)>,
#  <AdministrativeArea: AdministrativeArea object (2663)>,
#  <AdministrativeArea: AdministrativeArea object (2664)>,
#  <AdministrativeArea: AdministrativeArea object (2665)>,
#  <AdministrativeArea: AdministrativeArea object (2666)>,
#  <AdministrativeArea: AdministrativeArea object (2667)>,
#  <AdministrativeArea: AdministrativeArea object (2668)>,
#  <AdministrativeArea: AdministrativeArea object (2669)>,
#  <AdministrativeArea: AdministrativeArea object (2670)>,
#  <AdministrativeArea: AdministrativeArea object (2671)>,
#  <AdministrativeArea: AdministrativeArea object (2672)>,
#  <AdministrativeArea: AdministrativeArea object (2673)>,
#  <AdministrativeArea: AdministrativeArea object (2674)>,
#  <AdministrativeArea: AdministrativeArea object (2675)>,
#  <AdministrativeArea: AdministrativeArea object (2676)>,
#  <AdministrativeArea: AdministrativeArea object (2677)>,
#  <AdministrativeArea: AdministrativeArea object (2678)>,
#  <AdministrativeArea: AdministrativeArea object (2679)>,
#  <AdministrativeArea: AdministrativeArea object (2680)>,
#  <AdministrativeArea: AdministrativeArea object (2681)>,
#  <AdministrativeArea: AdministrativeArea object (2682)>,
#  <AdministrativeArea: AdministrativeArea object (2683)>,
#  <AdministrativeArea: AdministrativeArea object (2684)>,
#  <AdministrativeArea: AdministrativeArea object (2685)>,
#  <AdministrativeArea: AdministrativeArea object (2686)>,
#  <AdministrativeArea: AdministrativeArea object (2687)>,
#  <AdministrativeArea: AdministrativeArea object (2688)>,
#  <AdministrativeArea: AdministrativeArea object (2689)>,
#  <AdministrativeArea: AdministrativeArea object (2690)>,
#  <AdministrativeArea: AdministrativeArea object (2691)>,
#  <AdministrativeArea: AdministrativeArea object (2692)>,
#  <AdministrativeArea: AdministrativeArea object (2693)>,
#  <AdministrativeArea: AdministrativeArea object (2694)>,
#  <AdministrativeArea: AdministrativeArea object (2695)>,
#  <AdministrativeArea: AdministrativeArea object (2696)>,
#  <AdministrativeArea: AdministrativeArea object (2697)>,
#  <AdministrativeArea: AdministrativeArea object (2698)>,
#  <AdministrativeArea: AdministrativeArea object (2699)>,
#  <AdministrativeArea: AdministrativeArea object (2700)>,
#  <AdministrativeArea: AdministrativeArea object (2701)>,
#  <AdministrativeArea: AdministrativeArea object (2702)>,
#  <AdministrativeArea: AdministrativeArea object (2703)>,
#  <AdministrativeArea: AdministrativeArea object (2704)>,
#  <AdministrativeArea: AdministrativeArea object (2705)>,
#  <AdministrativeArea: AdministrativeArea object (2706)>,
#  <AdministrativeArea: AdministrativeArea object (2707)>,
#  <AdministrativeArea: AdministrativeArea object (2708)>,
#  <AdministrativeArea: AdministrativeArea object (2709)>,
#  <AdministrativeArea: AdministrativeArea object (2710)>,
#  <AdministrativeArea: AdministrativeArea object (2711)>,
#  <AdministrativeArea: AdministrativeArea object (2712)>,
#  <AdministrativeArea: AdministrativeArea object (2713)>,
#  <AdministrativeArea: AdministrativeArea object (2714)>,
#  <AdministrativeArea: AdministrativeArea object (2715)>,
#  <AdministrativeArea: AdministrativeArea object (2716)>,
#  <AdministrativeArea: AdministrativeArea object (2717)>,
#  <AdministrativeArea: AdministrativeArea object (2718)>,
#  <AdministrativeArea: AdministrativeArea object (2719)>,
#  <AdministrativeArea: AdministrativeArea object (2720)>,
#  <AdministrativeArea: AdministrativeArea object (2721)>,
#  <AdministrativeArea: AdministrativeArea object (2722)>,
#  <AdministrativeArea: AdministrativeArea object (2723)>,
#  <AdministrativeArea: AdministrativeArea object (2724)>,
#  <AdministrativeArea: AdministrativeArea object (2725)>,
#  <AdministrativeArea: AdministrativeArea object (2726)>,
#  <AdministrativeArea: AdministrativeArea object (2727)>,
#  <AdministrativeArea: AdministrativeArea object (2728)>,
#  <AdministrativeArea: AdministrativeArea object (2729)>,
#  <AdministrativeArea: AdministrativeArea object (2730)>,
#  <AdministrativeArea: AdministrativeArea object (2731)>,
#  <AdministrativeArea: AdministrativeArea object (2732)>,
#  <AdministrativeArea: AdministrativeArea object (2733)>,
#  <AdministrativeArea: AdministrativeArea object (2734)>,
#  <AdministrativeArea: AdministrativeArea object (2735)>,
#  <AdministrativeArea: AdministrativeArea object (2736)>,
#  <AdministrativeArea: AdministrativeArea object (2737)>,
#  <AdministrativeArea: AdministrativeArea object (2738)>,
#  <AdministrativeArea: AdministrativeArea object (2739)>,
#  <AdministrativeArea: AdministrativeArea object (2740)>,
#  <AdministrativeArea: AdministrativeArea object (2741)>,
#  <AdministrativeArea: AdministrativeArea object (2742)>,
#  <AdministrativeArea: AdministrativeArea object (2743)>,
#  <AdministrativeArea: AdministrativeArea object (2744)>,
#  <AdministrativeArea: AdministrativeArea object (2745)>,
#  <AdministrativeArea: AdministrativeArea object (2746)>,
#  <AdministrativeArea: AdministrativeArea object (2747)>,
#  <AdministrativeArea: AdministrativeArea object (2748)>,
#  <AdministrativeArea: AdministrativeArea object (2749)>,
#  <AdministrativeArea: AdministrativeArea object (2750)>,
#  <AdministrativeArea: AdministrativeArea object (2751)>,
#  <AdministrativeArea: AdministrativeArea object (2752)>,
#  <AdministrativeArea: AdministrativeArea object (2753)>,
#  <AdministrativeArea: AdministrativeArea object (2754)>,
#  <AdministrativeArea: AdministrativeArea object (2755)>,
#  <AdministrativeArea: AdministrativeArea object (2756)>,
#  <AdministrativeArea: AdministrativeArea object (2757)>,
#  <AdministrativeArea: AdministrativeArea object (2758)>,
#  <AdministrativeArea: AdministrativeArea object (2759)>,
#  <AdministrativeArea: AdministrativeArea object (2760)>,
#  <AdministrativeArea: AdministrativeArea object (2761)>,
#  <AdministrativeArea: AdministrativeArea object (2762)>,
#  <AdministrativeArea: AdministrativeArea object (2763)>,
#  <AdministrativeArea: AdministrativeArea object (2764)>,
#  <AdministrativeArea: AdministrativeArea object (2765)>,
#  <AdministrativeArea: AdministrativeArea object (2766)>,
#  <AdministrativeArea: AdministrativeArea object (2767)>,
#  <AdministrativeArea: AdministrativeArea object (2768)>,
#  <AdministrativeArea: AdministrativeArea object (2769)>,
#  <AdministrativeArea: AdministrativeArea object (2770)>,
#  <AdministrativeArea: AdministrativeArea object (2771)>,
#  <AdministrativeArea: AdministrativeArea object (2772)>,
#  <AdministrativeArea: AdministrativeArea object (2773)>,
#  <AdministrativeArea: AdministrativeArea object (2774)>,
#  <AdministrativeArea: AdministrativeArea object (2775)>,
#  <AdministrativeArea: AdministrativeArea object (2776)>,
#  <AdministrativeArea: AdministrativeArea object (2777)>,
#  <AdministrativeArea: AdministrativeArea object (2778)>,
#  <AdministrativeArea: AdministrativeArea object (2779)>,
#  <AdministrativeArea: AdministrativeArea object (2780)>,
#  <AdministrativeArea: AdministrativeArea object (2781)>,
#  <AdministrativeArea: AdministrativeArea object (2782)>,
#  <AdministrativeArea: AdministrativeArea object (2783)>,
#  <AdministrativeArea: AdministrativeArea object (2784)>,
#  <AdministrativeArea: AdministrativeArea object (2785)>,
#  <AdministrativeArea: AdministrativeArea object (2786)>,
#  <AdministrativeArea: AdministrativeArea object (2787)>,
#  <AdministrativeArea: AdministrativeArea object (2788)>,
#  <AdministrativeArea: AdministrativeArea object (2789)>,
#  <AdministrativeArea: AdministrativeArea object (2790)>,
#  <AdministrativeArea: AdministrativeArea object (2791)>,
#  <AdministrativeArea: AdministrativeArea object (2792)>,
#  <AdministrativeArea: AdministrativeArea object (2793)>,
#  <AdministrativeArea: AdministrativeArea object (2794)>,
#  <AdministrativeArea: AdministrativeArea object (2795)>,
#  <AdministrativeArea: AdministrativeArea object (2796)>,
#  <AdministrativeArea: AdministrativeArea object (2797)>,
#  <AdministrativeArea: AdministrativeArea object (2798)>,
#  <AdministrativeArea: AdministrativeArea object (2799)>,
#  <AdministrativeArea: AdministrativeArea object (2800)>,
#  <AdministrativeArea: AdministrativeArea object (2801)>,
#  <AdministrativeArea: AdministrativeArea object (2802)>,
#  <AdministrativeArea: AdministrativeArea object (2803)>,
#  <AdministrativeArea: AdministrativeArea object (2804)>,
#  <AdministrativeArea: AdministrativeArea object (2805)>,
#  <AdministrativeArea: AdministrativeArea object (2806)>,
#  <AdministrativeArea: AdministrativeArea object (2807)>,
#  <AdministrativeArea: AdministrativeArea object (2808)>,
#  <AdministrativeArea: AdministrativeArea object (2809)>,
#  <AdministrativeArea: AdministrativeArea object (2810)>,
#  <AdministrativeArea: AdministrativeArea object (2811)>,
#  <AdministrativeArea: AdministrativeArea object (2812)>,
#  <AdministrativeArea: AdministrativeArea object (2813)>,
#  <AdministrativeArea: AdministrativeArea object (2814)>,
#  <AdministrativeArea: AdministrativeArea object (2815)>,
#  <AdministrativeArea: AdministrativeArea object (2816)>,
#  <AdministrativeArea: AdministrativeArea object (2817)>,
#  <AdministrativeArea: AdministrativeArea object (2818)>,
#  <AdministrativeArea: AdministrativeArea object (2819)>,
#  <AdministrativeArea: AdministrativeArea object (2820)>,
#  <AdministrativeArea: AdministrativeArea object (2821)>,
#  <AdministrativeArea: AdministrativeArea object (2822)>,
#  <AdministrativeArea: AdministrativeArea object (2823)>,
#  <AdministrativeArea: AdministrativeArea object (2824)>,
#  <AdministrativeArea: AdministrativeArea object (2825)>,
#  <AdministrativeArea: AdministrativeArea object (2826)>,
#  <AdministrativeArea: AdministrativeArea object (2827)>,
#  <AdministrativeArea: AdministrativeArea object (2828)>,
#  <AdministrativeArea: AdministrativeArea object (2829)>,
#  <AdministrativeArea: AdministrativeArea object (2830)>,
#  <AdministrativeArea: AdministrativeArea object (2831)>,
#  <AdministrativeArea: AdministrativeArea object (2832)>,
#  <AdministrativeArea: AdministrativeArea object (2833)>,
#  <AdministrativeArea: AdministrativeArea object (2834)>,
#  <AdministrativeArea: AdministrativeArea object (2835)>,
#  <AdministrativeArea: AdministrativeArea object (2836)>,
#  <AdministrativeArea: AdministrativeArea object (2837)>,
#  <AdministrativeArea: AdministrativeArea object (2838)>,
#  <AdministrativeArea: AdministrativeArea object (2839)>,
#  <AdministrativeArea: AdministrativeArea object (2840)>,
#  <AdministrativeArea: AdministrativeArea object (2841)>,
#  <AdministrativeArea: AdministrativeArea object (2842)>,
#  <AdministrativeArea: AdministrativeArea object (2843)>,
#  <AdministrativeArea: AdministrativeArea object (2844)>,
#  <AdministrativeArea: AdministrativeArea object (2845)>,
#  <AdministrativeArea: AdministrativeArea object (2846)>,
#  <AdministrativeArea: AdministrativeArea object (2847)>,
#  <AdministrativeArea: AdministrativeArea object (2848)>,
#  <AdministrativeArea: AdministrativeArea object (2849)>,
#  <AdministrativeArea: AdministrativeArea object (2850)>,
#  <AdministrativeArea: AdministrativeArea object (2851)>,
#  <AdministrativeArea: AdministrativeArea object (2852)>,
#  <AdministrativeArea: AdministrativeArea object (2853)>,
#  <AdministrativeArea: AdministrativeArea object (2854)>,
#  <AdministrativeArea: AdministrativeArea object (2855)>,
#  <AdministrativeArea: AdministrativeArea object (2856)>,
#  <AdministrativeArea: AdministrativeArea object (2857)>,
#  <AdministrativeArea: AdministrativeArea object (2858)>,
#  <AdministrativeArea: AdministrativeArea object (2859)>,
#  <AdministrativeArea: AdministrativeArea object (2860)>,
#  <AdministrativeArea: AdministrativeArea object (2861)>,
#  <AdministrativeArea: AdministrativeArea object (2862)>,
#  <AdministrativeArea: AdministrativeArea object (2863)>,
#  <AdministrativeArea: AdministrativeArea object (2864)>,
#  <AdministrativeArea: AdministrativeArea object (2865)>,
#  <AdministrativeArea: AdministrativeArea object (2866)>,
#  <AdministrativeArea: AdministrativeArea object (2867)>,
#  <AdministrativeArea: AdministrativeArea object (2868)>,
#  <AdministrativeArea: AdministrativeArea object (2869)>,
#  <AdministrativeArea: AdministrativeArea object (2870)>,
#  <AdministrativeArea: AdministrativeArea object (2871)>,
#  <AdministrativeArea: AdministrativeArea object (2872)>,
#  <AdministrativeArea: AdministrativeArea object (2873)>,
#  <AdministrativeArea: AdministrativeArea object (2874)>,
#  <AdministrativeArea: AdministrativeArea object (2875)>,
#  <AdministrativeArea: AdministrativeArea object (2876)>,
#  <AdministrativeArea: AdministrativeArea object (2877)>,
#  <AdministrativeArea: AdministrativeArea object (2878)>,
#  <AdministrativeArea: AdministrativeArea object (2879)>,
#  <AdministrativeArea: AdministrativeArea object (2880)>,
#  <AdministrativeArea: AdministrativeArea object (2881)>,
#  <AdministrativeArea: AdministrativeArea object (2882)>,
#  <AdministrativeArea: AdministrativeArea object (2883)>,
#  <AdministrativeArea: AdministrativeArea object (2884)>,
#  <AdministrativeArea: AdministrativeArea object (2885)>,
#  <AdministrativeArea: AdministrativeArea object (2886)>,
#  <AdministrativeArea: AdministrativeArea object (2887)>,
#  <AdministrativeArea: AdministrativeArea object (2888)>,
#  <AdministrativeArea: AdministrativeArea object (2889)>,
#  <AdministrativeArea: AdministrativeArea object (2890)>,
#  <AdministrativeArea: AdministrativeArea object (2891)>,
#  <AdministrativeArea: AdministrativeArea object (2892)>,
#  <AdministrativeArea: AdministrativeArea object (2893)>,
#  <AdministrativeArea: AdministrativeArea object (2894)>,
#  <AdministrativeArea: AdministrativeArea object (2895)>,
#  <AdministrativeArea: AdministrativeArea object (2896)>,
#  <AdministrativeArea: AdministrativeArea object (2897)>,
#  <AdministrativeArea: AdministrativeArea object (2898)>,
#  <AdministrativeArea: AdministrativeArea object (2899)>,
#  <AdministrativeArea: AdministrativeArea object (2900)>,
#  <AdministrativeArea: AdministrativeArea object (2901)>,
#  <AdministrativeArea: AdministrativeArea object (2902)>,
#  <AdministrativeArea: AdministrativeArea object (2903)>,
#  <AdministrativeArea: AdministrativeArea object (2904)>,
#  <AdministrativeArea: AdministrativeArea object (2905)>,
#  <AdministrativeArea: AdministrativeArea object (2906)>,
#  <AdministrativeArea: AdministrativeArea object (2907)>,
#  <AdministrativeArea: AdministrativeArea object (2908)>,
#  <AdministrativeArea: AdministrativeArea object (2909)>,
#  <AdministrativeArea: AdministrativeArea object (2910)>,
#  <AdministrativeArea: AdministrativeArea object (2911)>,
#  <AdministrativeArea: AdministrativeArea object (2912)>,
#  <AdministrativeArea: AdministrativeArea object (2913)>,
#  <AdministrativeArea: AdministrativeArea object (2914)>,
#  <AdministrativeArea: AdministrativeArea object (2915)>,
#  <AdministrativeArea: AdministrativeArea object (2916)>,
#  <AdministrativeArea: AdministrativeArea object (2917)>,
#  <AdministrativeArea: AdministrativeArea object (2918)>,
#  <AdministrativeArea: AdministrativeArea object (2919)>,
#  <AdministrativeArea: AdministrativeArea object (2920)>,
#  <AdministrativeArea: AdministrativeArea object (2921)>,
#  <AdministrativeArea: AdministrativeArea object (2922)>,
#  <AdministrativeArea: AdministrativeArea object (2923)>,
#  <AdministrativeArea: AdministrativeArea object (2924)>,
#  <AdministrativeArea: AdministrativeArea object (2925)>,
#  <AdministrativeArea: AdministrativeArea object (2926)>,
#  <AdministrativeArea: AdministrativeArea object (2927)>,
#  <AdministrativeArea: AdministrativeArea object (2928)>,
#  <AdministrativeArea: AdministrativeArea object (2929)>,
#  <AdministrativeArea: AdministrativeArea object (2930)>,
#  <AdministrativeArea: AdministrativeArea object (2931)>,
#  <AdministrativeArea: AdministrativeArea object (2932)>,
#  <AdministrativeArea: AdministrativeArea object (2933)>,
#  <AdministrativeArea: AdministrativeArea object (2934)>,
#  <AdministrativeArea: AdministrativeArea object (2935)>,
#  <AdministrativeArea: AdministrativeArea object (2936)>,
#  <AdministrativeArea: AdministrativeArea object (2937)>,
#  <AdministrativeArea: AdministrativeArea object (2938)>,
#  <AdministrativeArea: AdministrativeArea object (2939)>,
#  <AdministrativeArea: AdministrativeArea object (2940)>,
#  <AdministrativeArea: AdministrativeArea object (2941)>,
#  <AdministrativeArea: AdministrativeArea object (2942)>,
#  <AdministrativeArea: AdministrativeArea object (2943)>,
#  <AdministrativeArea: AdministrativeArea object (2944)>,
#  <AdministrativeArea: AdministrativeArea object (2945)>,
#  <AdministrativeArea: AdministrativeArea object (2946)>,
#  <AdministrativeArea: AdministrativeArea object (2947)>,
#  <AdministrativeArea: AdministrativeArea object (2948)>,
#  <AdministrativeArea: AdministrativeArea object (2949)>,
#  <AdministrativeArea: AdministrativeArea object (2950)>,
#  <AdministrativeArea: AdministrativeArea object (2951)>,
#  <AdministrativeArea: AdministrativeArea object (2952)>,
#  <AdministrativeArea: AdministrativeArea object (2953)>,
#  <AdministrativeArea: AdministrativeArea object (2954)>,
#  <AdministrativeArea: AdministrativeArea object (2955)>,
#  <AdministrativeArea: AdministrativeArea object (2956)>,
#  <AdministrativeArea: AdministrativeArea object (2957)>,
#  <AdministrativeArea: AdministrativeArea object (2958)>,
#  <AdministrativeArea: AdministrativeArea object (2959)>,
#  <AdministrativeArea: AdministrativeArea object (2960)>,
#  <AdministrativeArea: AdministrativeArea object (2961)>,
#  <AdministrativeArea: AdministrativeArea object (2962)>,
#  <AdministrativeArea: AdministrativeArea object (2963)>,
#  <AdministrativeArea: AdministrativeArea object (2964)>,
#  <AdministrativeArea: AdministrativeArea object (2965)>,
#  <AdministrativeArea: AdministrativeArea object (2966)>,
#  <AdministrativeArea: AdministrativeArea object (2967)>,
#  <AdministrativeArea: AdministrativeArea object (2968)>,
#  <AdministrativeArea: AdministrativeArea object (2969)>,
#  <AdministrativeArea: AdministrativeArea object (2970)>,
#  <AdministrativeArea: AdministrativeArea object (2971)>,
#  <AdministrativeArea: AdministrativeArea object (2972)>,
#  <AdministrativeArea: AdministrativeArea object (2973)>,
#  <AdministrativeArea: AdministrativeArea object (2974)>,
#  <AdministrativeArea: AdministrativeArea object (2975)>,
#  <AdministrativeArea: AdministrativeArea object (2976)>,
#  <AdministrativeArea: AdministrativeArea object (2977)>,
#  <AdministrativeArea: AdministrativeArea object (2978)>,
#  <AdministrativeArea: AdministrativeArea object (2979)>,
#  <AdministrativeArea: AdministrativeArea object (2980)>,
#  <AdministrativeArea: AdministrativeArea object (2981)>,
#  <AdministrativeArea: AdministrativeArea object (2982)>,
#  <AdministrativeArea: AdministrativeArea object (2983)>,
#  <AdministrativeArea: AdministrativeArea object (2984)>,
#  <AdministrativeArea: AdministrativeArea object (2985)>,
#  <AdministrativeArea: AdministrativeArea object (2986)>,
#  <AdministrativeArea: AdministrativeArea object (2987)>,
#  <AdministrativeArea: AdministrativeArea object (2988)>,
#  <AdministrativeArea: AdministrativeArea object (2989)>,
#  <AdministrativeArea: AdministrativeArea object (2990)>,
#  <AdministrativeArea: AdministrativeArea object (2991)>,
#  <AdministrativeArea: AdministrativeArea object (2992)>,
#  <AdministrativeArea: AdministrativeArea object (2993)>,
#  <AdministrativeArea: AdministrativeArea object (2994)>,
#  <AdministrativeArea: AdministrativeArea object (2995)>,
#  <AdministrativeArea: AdministrativeArea object (2996)>,
#  <AdministrativeArea: AdministrativeArea object (2997)>,
#  <AdministrativeArea: AdministrativeArea object (2998)>,
#  <AdministrativeArea: AdministrativeArea object (2999)>,
#  <AdministrativeArea: AdministrativeArea object (3000)>,
#  <AdministrativeArea: AdministrativeArea object (3001)>,
#  <AdministrativeArea: AdministrativeArea object (3002)>,
#  <AdministrativeArea: AdministrativeArea object (3003)>,
#  <AdministrativeArea: AdministrativeArea object (3004)>,
#  <AdministrativeArea: AdministrativeArea object (3005)>,
#  <AdministrativeArea: AdministrativeArea object (3006)>,
#  <AdministrativeArea: AdministrativeArea object (3007)>,
#  <AdministrativeArea: AdministrativeArea object (3008)>,
#  <AdministrativeArea: AdministrativeArea object (3009)>,
#  <AdministrativeArea: AdministrativeArea object (3010)>,
#  <AdministrativeArea: AdministrativeArea object (3011)>,
#  <AdministrativeArea: AdministrativeArea object (3012)>,
#  <AdministrativeArea: AdministrativeArea object (3013)>,
#  <AdministrativeArea: AdministrativeArea object (3014)>,
#  <AdministrativeArea: AdministrativeArea object (3015)>,
#  <AdministrativeArea: AdministrativeArea object (3016)>,
#  <AdministrativeArea: AdministrativeArea object (3017)>,
#  <AdministrativeArea: AdministrativeArea object (3018)>,
#  <AdministrativeArea: AdministrativeArea object (3019)>,
#  <AdministrativeArea: AdministrativeArea object (3020)>,
#  <AdministrativeArea: AdministrativeArea object (3021)>,
#  <AdministrativeArea: AdministrativeArea object (3022)>,
#  <AdministrativeArea: AdministrativeArea object (3023)>,
#  <AdministrativeArea: AdministrativeArea object (3024)>,
#  <AdministrativeArea: AdministrativeArea object (3025)>,
#  <AdministrativeArea: AdministrativeArea object (3026)>,
#  <AdministrativeArea: AdministrativeArea object (3027)>,
#  <AdministrativeArea: AdministrativeArea object (3028)>,
#  <AdministrativeArea: AdministrativeArea object (3029)>,
#  <AdministrativeArea: AdministrativeArea object (3030)>,
#  <AdministrativeArea: AdministrativeArea object (3031)>,
#  <AdministrativeArea: AdministrativeArea object (3032)>,
#  <AdministrativeArea: AdministrativeArea object (3033)>,
#  <AdministrativeArea: AdministrativeArea object (3034)>,
#  <AdministrativeArea: AdministrativeArea object (3035)>,
#  <AdministrativeArea: AdministrativeArea object (3036)>,
#  <AdministrativeArea: AdministrativeArea object (3037)>,
#  <AdministrativeArea: AdministrativeArea object (3038)>,
#  <AdministrativeArea: AdministrativeArea object (3039)>,
#  <AdministrativeArea: AdministrativeArea object (3040)>,
#  <AdministrativeArea: AdministrativeArea object (3041)>,
#  <AdministrativeArea: AdministrativeArea object (3042)>,
#  <AdministrativeArea: AdministrativeArea object (3043)>,
#  <AdministrativeArea: AdministrativeArea object (3044)>,
#  <AdministrativeArea: AdministrativeArea object (3045)>,
#  <AdministrativeArea: AdministrativeArea object (3046)>,
#  <AdministrativeArea: AdministrativeArea object (3047)>,
#  <AdministrativeArea: AdministrativeArea object (3048)>,
#  <AdministrativeArea: AdministrativeArea object (3049)>,
#  <AdministrativeArea: AdministrativeArea object (3050)>,
#  <AdministrativeArea: AdministrativeArea object (3051)>,
#  <AdministrativeArea: AdministrativeArea object (3052)>,
#  <AdministrativeArea: AdministrativeArea object (3053)>,
#  <AdministrativeArea: AdministrativeArea object (3054)>,
#  <AdministrativeArea: AdministrativeArea object (3055)>,
#  <AdministrativeArea: AdministrativeArea object (3056)>,
#  <AdministrativeArea: AdministrativeArea object (3057)>,
#  <AdministrativeArea: AdministrativeArea object (3058)>,
#  <AdministrativeArea: AdministrativeArea object (3059)>,
#  <AdministrativeArea: AdministrativeArea object (3060)>,
#  <AdministrativeArea: AdministrativeArea object (3061)>,
#  <AdministrativeArea: AdministrativeArea object (3062)>,
#  <AdministrativeArea: AdministrativeArea object (3063)>,
#  <AdministrativeArea: AdministrativeArea object (3064)>,
#  <AdministrativeArea: AdministrativeArea object (3065)>,
#  <AdministrativeArea: AdministrativeArea object (3066)>,
#  <AdministrativeArea: AdministrativeArea object (3067)>,
#  <AdministrativeArea: AdministrativeArea object (3068)>,
#  <AdministrativeArea: AdministrativeArea object (3069)>,
#  <AdministrativeArea: AdministrativeArea object (3070)>,
#  <AdministrativeArea: AdministrativeArea object (3071)>,
#  <AdministrativeArea: AdministrativeArea object (3072)>,
#  <AdministrativeArea: AdministrativeArea object (3073)>,
#  <AdministrativeArea: AdministrativeArea object (3074)>,
#  <AdministrativeArea: AdministrativeArea object (3075)>,
#  <AdministrativeArea: AdministrativeArea object (3076)>,
#  <AdministrativeArea: AdministrativeArea object (3077)>,
#  <AdministrativeArea: AdministrativeArea object (3078)>,
#  <AdministrativeArea: AdministrativeArea object (3079)>,
#  <AdministrativeArea: AdministrativeArea object (3080)>,
#  <AdministrativeArea: AdministrativeArea object (3081)>,
#  <AdministrativeArea: AdministrativeArea object (3082)>,
#  <AdministrativeArea: AdministrativeArea object (3083)>,
#  <AdministrativeArea: AdministrativeArea object (3084)>,
#  <AdministrativeArea: AdministrativeArea object (3085)>,
#  <AdministrativeArea: AdministrativeArea object (3086)>,
#  <AdministrativeArea: AdministrativeArea object (3087)>,
#  <AdministrativeArea: AdministrativeArea object (3088)>,
#  <AdministrativeArea: AdministrativeArea object (3089)>,
#  <AdministrativeArea: AdministrativeArea object (3090)>,
#  <AdministrativeArea: AdministrativeArea object (3091)>,
#  <AdministrativeArea: AdministrativeArea object (3092)>,
#  <AdministrativeArea: AdministrativeArea object (3093)>,
#  <AdministrativeArea: AdministrativeArea object (3094)>,
#  <AdministrativeArea: AdministrativeArea object (3095)>,
#  <AdministrativeArea: AdministrativeArea object (3096)>,
#  <AdministrativeArea: AdministrativeArea object (3097)>,
#  <AdministrativeArea: AdministrativeArea object (3098)>,
#  <AdministrativeArea: AdministrativeArea object (3099)>,
#  <AdministrativeArea: AdministrativeArea object (3100)>,
#  <AdministrativeArea: AdministrativeArea object (3101)>,
#  <AdministrativeArea: AdministrativeArea object (3102)>,
#  <AdministrativeArea: AdministrativeArea object (3103)>,
#  <AdministrativeArea: AdministrativeArea object (3104)>,
#  <AdministrativeArea: AdministrativeArea object (3105)>,
#  <AdministrativeArea: AdministrativeArea object (3106)>,
#  <AdministrativeArea: AdministrativeArea object (3107)>,
#  <AdministrativeArea: AdministrativeArea object (3108)>,
#  <AdministrativeArea: AdministrativeArea object (3109)>,
#  <AdministrativeArea: AdministrativeArea object (3110)>,
#  <AdministrativeArea: AdministrativeArea object (3111)>,
#  <AdministrativeArea: AdministrativeArea object (3112)>,
#  <AdministrativeArea: AdministrativeArea object (3113)>,
#  <AdministrativeArea: AdministrativeArea object (3114)>,
#  <AdministrativeArea: AdministrativeArea object (3115)>,
#  <AdministrativeArea: AdministrativeArea object (3116)>,
#  <AdministrativeArea: AdministrativeArea object (3117)>,
#  <AdministrativeArea: AdministrativeArea object (3118)>,
#  <AdministrativeArea: AdministrativeArea object (3119)>,
#  <AdministrativeArea: AdministrativeArea object (3120)>,
#  <AdministrativeArea: AdministrativeArea object (3121)>,
#  <AdministrativeArea: AdministrativeArea object (3122)>,
#  <AdministrativeArea: AdministrativeArea object (3123)>,
#  <AdministrativeArea: AdministrativeArea object (3124)>,
#  <AdministrativeArea: AdministrativeArea object (3125)>,
#  <AdministrativeArea: AdministrativeArea object (3126)>,
#  <AdministrativeArea: AdministrativeArea object (3127)>,
#  <AdministrativeArea: AdministrativeArea object (3128)>,
#  <AdministrativeArea: AdministrativeArea object (3129)>,
#  <AdministrativeArea: AdministrativeArea object (3130)>,
#  <AdministrativeArea: AdministrativeArea object (3131)>,
#  <AdministrativeArea: AdministrativeArea object (3132)>,
#  <AdministrativeArea: AdministrativeArea object (3133)>,
#  <AdministrativeArea: AdministrativeArea object (3134)>,
#  <AdministrativeArea: AdministrativeArea object (3135)>,
#  <AdministrativeArea: AdministrativeArea object (3136)>,
#  <AdministrativeArea: AdministrativeArea object (3137)>,
#  <AdministrativeArea: AdministrativeArea object (3138)>,
#  <AdministrativeArea: AdministrativeArea object (3139)>,
#  <AdministrativeArea: AdministrativeArea object (3140)>,
#  <AdministrativeArea: AdministrativeArea object (3141)>,
#  <AdministrativeArea: AdministrativeArea object (3142)>,
#  <AdministrativeArea: AdministrativeArea object (3143)>,
#  <AdministrativeArea: AdministrativeArea object (3144)>,
#  <AdministrativeArea: AdministrativeArea object (3145)>,
#  <AdministrativeArea: AdministrativeArea object (3146)>,
#  <AdministrativeArea: AdministrativeArea object (3147)>,
#  <AdministrativeArea: AdministrativeArea object (3148)>,
#  <AdministrativeArea: AdministrativeArea object (3149)>,
#  <AdministrativeArea: AdministrativeArea object (3150)>,
#  <AdministrativeArea: AdministrativeArea object (3151)>,
#  <AdministrativeArea: AdministrativeArea object (3152)>,
#  <AdministrativeArea: AdministrativeArea object (3153)>,
#  <AdministrativeArea: AdministrativeArea object (3154)>,
#  <AdministrativeArea: AdministrativeArea object (3155)>,
#  <AdministrativeArea: AdministrativeArea object (3156)>,
#  <AdministrativeArea: AdministrativeArea object (3157)>,
#  <AdministrativeArea: AdministrativeArea object (3158)>,
#  <AdministrativeArea: AdministrativeArea object (3159)>,
#  <AdministrativeArea: AdministrativeArea object (3160)>,
#  <AdministrativeArea: AdministrativeArea object (3161)>,
#  <AdministrativeArea: AdministrativeArea object (3162)>,
#  <AdministrativeArea: AdministrativeArea object (3163)>,
#  <AdministrativeArea: AdministrativeArea object (3164)>,
#  <AdministrativeArea: AdministrativeArea object (3165)>,
#  <AdministrativeArea: AdministrativeArea object (3166)>,
#  <AdministrativeArea: AdministrativeArea object (3167)>,
#  <AdministrativeArea: AdministrativeArea object (3168)>,
#  <AdministrativeArea: AdministrativeArea object (3169)>,
#  <AdministrativeArea: AdministrativeArea object (3170)>,
#  <AdministrativeArea: AdministrativeArea object (3171)>,
#  <AdministrativeArea: AdministrativeArea object (3172)>,
#  <AdministrativeArea: AdministrativeArea object (3173)>,
#  <AdministrativeArea: AdministrativeArea object (3174)>,
#  <AdministrativeArea: AdministrativeArea object (3175)>,
#  <AdministrativeArea: AdministrativeArea object (3176)>,
#  <AdministrativeArea: AdministrativeArea object (3177)>,
#  <AdministrativeArea: AdministrativeArea object (3178)>,
#  <AdministrativeArea: AdministrativeArea object (3179)>,
#  <AdministrativeArea: AdministrativeArea object (3180)>,
#  <AdministrativeArea: AdministrativeArea object (3181)>,
#  <AdministrativeArea: AdministrativeArea object (3182)>,
#  <AdministrativeArea: AdministrativeArea object (3183)>,
#  <AdministrativeArea: AdministrativeArea object (3184)>,
#  <AdministrativeArea: AdministrativeArea object (3185)>,
#  <AdministrativeArea: AdministrativeArea object (3186)>,
#  <AdministrativeArea: AdministrativeArea object (3187)>,
#  <AdministrativeArea: AdministrativeArea object (3188)>,
#  <AdministrativeArea: AdministrativeArea object (3189)>,
#  <AdministrativeArea: AdministrativeArea object (3190)>,
#  <AdministrativeArea: AdministrativeArea object (3191)>,
#  <AdministrativeArea: AdministrativeArea object (3192)>,
#  <AdministrativeArea: AdministrativeArea object (3193)>,
#  <AdministrativeArea: AdministrativeArea object (3194)>,
#  <AdministrativeArea: AdministrativeArea object (3195)>,
#  <AdministrativeArea: AdministrativeArea object (3196)>,
#  <AdministrativeArea: AdministrativeArea object (3197)>,
#  <AdministrativeArea: AdministrativeArea object (3198)>,
#  <AdministrativeArea: AdministrativeArea object (3199)>,
#  <AdministrativeArea: AdministrativeArea object (3200)>,
#  <AdministrativeArea: AdministrativeArea object (3201)>,
#  <AdministrativeArea: AdministrativeArea object (3202)>,
#  <AdministrativeArea: AdministrativeArea object (3203)>,
#  <AdministrativeArea: AdministrativeArea object (3204)>,
#  <AdministrativeArea: AdministrativeArea object (3205)>,
#  <AdministrativeArea: AdministrativeArea object (3206)>,
#  <AdministrativeArea: AdministrativeArea object (3207)>,
#  <AdministrativeArea: AdministrativeArea object (3208)>,
#  <AdministrativeArea: AdministrativeArea object (3209)>,
#  <AdministrativeArea: AdministrativeArea object (3210)>,
#  <AdministrativeArea: AdministrativeArea object (3211)>,
#  <AdministrativeArea: AdministrativeArea object (3212)>,
#  <AdministrativeArea: AdministrativeArea object (3213)>,
#  <AdministrativeArea: AdministrativeArea object (3214)>,
#  <AdministrativeArea: AdministrativeArea object (3215)>,
#  <AdministrativeArea: AdministrativeArea object (3216)>,
#  <AdministrativeArea: AdministrativeArea object (3217)>,
#  <AdministrativeArea: AdministrativeArea object (3218)>,
#  <AdministrativeArea: AdministrativeArea object (3219)>,
#  <AdministrativeArea: AdministrativeArea object (3220)>,
#  <AdministrativeArea: AdministrativeArea object (3221)>,
#  <AdministrativeArea: AdministrativeArea object (3222)>,
#  <AdministrativeArea: AdministrativeArea object (3223)>,
#  <AdministrativeArea: AdministrativeArea object (3224)>,
#  <AdministrativeArea: AdministrativeArea object (3225)>,
#  <AdministrativeArea: AdministrativeArea object (3226)>,
#  <AdministrativeArea: AdministrativeArea object (3227)>,
#  <AdministrativeArea: AdministrativeArea object (3228)>,
#  <AdministrativeArea: AdministrativeArea object (3229)>,
#  <AdministrativeArea: AdministrativeArea object (3230)>,
#  <AdministrativeArea: AdministrativeArea object (3231)>,
#  <AdministrativeArea: AdministrativeArea object (3232)>,
#  <AdministrativeArea: AdministrativeArea object (3233)>,
#  <AdministrativeArea: AdministrativeArea object (3234)>,
#  <AdministrativeArea: AdministrativeArea object (3235)>,
#  ...]

# %%
models.AdministrativeArea.objects.create(name="hello")
# Out:
# <AdministrativeArea: AdministrativeArea object (2235)>

# %%
models.AdministrativeArea.objects.all().delete()
for item in areas.index:
    print(item)
