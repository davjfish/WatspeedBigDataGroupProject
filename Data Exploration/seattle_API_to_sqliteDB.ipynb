# %%
import requests
import json
import pandas as pd
import sqlite3
import numpy as np

# %%
# Define the API endpoint URL
# We will use a public test API to get a list of posts
api_url = 'https://data.seattle.gov/resource/33kz-ixgy.json' #police calls

# read in data from API to a dataframe
df_seattle = pd.read_json(api_url)

# %%
df_seattle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 46 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   cad_event_number                                    1000 non-null   int64
#  1   cad_event_clearance_description                     1000 non-null   object
#  2   call_type                                           1000 non-null   object
#  3   priority                                            1000 non-null   int64
#  4   initial_call_type                                   1000 non-null   object
#  5   final_call_type                                     1000 non-null   object
#  6   cad_event_original_time_queued                      1000 non-null   object
#  7   cad_event_arrived_time                              937 non-null    datetime64[ns]
#  8   dispatch_precinct                                   1000 non-null   object
#  9   dispatch_sector                                     991 non-null    object
#  10  dispatch_beat                                       1000 non-null   object
#  11  dispatch_longitude                                  1000 non-null   object
#  12  dispatch_latitude                                   1000 non-null   object
#  13  dispatch_reporting_area                             1000 non-null   object
#  14  cad_event_response_category                         1000 non-null   object
#  15  call_sign_dispatch_id                               1000 non-null   object
#  16  call_sign_dispatch_time                             1000 non-null   datetime64[ns]
#  17  first_spd_call_sign_at_scene_time                   929 non-null    datetime64[ns]
#  18  first_spd_call_sign_dispatch_time                   993 non-null    datetime64[ns]
#  19  last_spd_call_sign_in_service_time                  993 non-null    datetime64[ns]
#  20  spd_call_sign_total_service_time_s_                 993 non-null    float64
#  21  call_sign_total_service_time_s_                     1000 non-null   int64
#  22  first_spd_call_sign_dispatch_delay_time_s_          993 non-null    float64
#  23  first_spd_call_sign_response_time_s_                929 non-null    float64
#  24  call_sign_dispatch_delay_time_s_                    1000 non-null   int64
#  25  call_sign_response_time_s_                          800 non-null    float64
#  26  call_sign_at_scene_time                             800 non-null    datetime64[ns]
#  27  cad_event_first_response_time_s_                    937 non-null    float64
#  28  call_sign_in_service_time                           1000 non-null   datetime64[ns]
#  29  call_type_indicator                                 1000 non-null   object
#  30  dispatch_neighborhood                               1000 non-null   object
#  31  call_type_received_classification                   1000 non-null   object
#  32  dispatch_address                                    1000 non-null   object
#  33  count_of_officers                                   1000 non-null   int64
#  34  first_care_call_sign_at_scene_time                  5 non-null      datetime64[ns]
#  35  first_care_call_sign_dispatch_time                  7 non-null      datetime64[ns]
#  36  last_care_call_sign_in_service_time                 7 non-null      datetime64[ns]
#  37  care_call_sign_total_service_time_s_                7 non-null      float64
#  38  first_care_call_sign_dispatch_delay_time_s_         7 non-null      float64
#  39  first_care_call_sign_response_time_s_               5 non-null      float64
#  40  first_co_response_call_sign_at_scene_time           8 non-null      datetime64[ns]
#  41  first_co_response_call_sign_dispatch_time           8 non-null      datetime64[ns]
#  42  last_co_response_call_sign_in_service_time          8 non-null      datetime64[ns]
#  43  co_response_call_sign_total_service_time_s_         8 non-null      float64
#  44  first_co_response_call_sign_dispatch_delay_time_s_  8 non-null      float64
#  45  first_co_response_call_sign_response_time_s_        8 non-null      float64
# dtypes: datetime64[ns](13), float64(11), int64(5), object(17)
# memory usage: 359.5+ KB

# %%
df_township = pd.DataFrame()
df_responseunit = pd.DataFrame()
df_category = pd.DataFrame()

df_township['name'] = df_seattle['dispatch_neighborhood'].unique()
df_responseunit['station_name'] = df_seattle['dispatch_precinct'].unique()
df_category['name'] = df_seattle['initial_call_type'].unique()

df_township = df_township.reset_index()
df_responseunit = df_responseunit.reset_index()
df_category = df_category.reset_index()

df_township = df_township.rename(columns={'index': 'id'})
df_responseunit = df_responseunit.rename(columns={'index': 'id'})
df_category = df_category.rename(columns={'index': 'id'})
df_responsetype = pd.DataFrame({'id':[0],'name':['POLICE']})

# %%
df_emergencycall = df_seattle[['cad_event_original_time_queued','dispatch_address',
     'dispatch_latitude','dispatch_longitude']]
df_emergencycall = df_emergencycall.reset_index()

# generate category_id col
cat_id = []
for v in df_seattle['initial_call_type']:
    cat_id.append(df_category[df_category['name'] == v].id.iloc[0])
df_emergencycall['category_id'] = cat_id

# generate response_unit_id col
ru_id = []
for v in df_seattle['dispatch_precinct']:
    ru_id.append(df_responseunit[df_responseunit['station_name'] == v].id.iloc[0])
df_emergencycall['response_unit_id'] = ru_id
df_emergencycall['zip_code'] = np.NaN

# generate township_id col
ts_id = []
for v in df_seattle['dispatch_neighborhood']:
    ts_id.append(df_township[df_township['name'] == v].id.iloc[0])
df_emergencycall['township_id'] = ts_id

# view the DF
df_emergencycall
# Out:
#      index cad_event_original_time_queued               dispatch_address  \
# 0        0        2017-01-25T11:14:52.000           9XX BLOCK OF N 77 ST
# 1        1        2017-01-25T14:29:56.000        12XX BLOCK OF S KING ST
# 2        2        2024-08-14T16:46:04.000      12XX BLOCK OF S WELLER ST
# 3        3        2017-01-25T21:36:03.000     42XX BLOCK OF SW ALASKA ST
# 4        4        2024-08-16T15:35:12.000    11XX BLOCK OF HIAWATHA PL S
# ..     ...                            ...                            ...
# 995    995        2021-09-06T01:08:05.000         52XX BLOCK OF 45 AV SW
# 996    996        2021-09-07T12:43:12.000     100XX BLOCK OF AURORA AV N
# 997    997        2021-09-11T06:13:08.000          44XX BLOCK OF 41 AV S
# 998    998        2021-09-13T04:56:12.000   5XX BLOCK OF NE NORTHGATE WY
# 999    999        2021-09-14T16:42:22.000  78XX BLOCK OF LAKE CITY WY NE
#
#     dispatch_latitude dispatch_longitude  category_id  response_unit_id  \
# 0         47.68476561      -122.34585468            0                 0
# 1         47.59833443      -122.31531757            1                 1
# 2         47.59749563      -122.31499334            2                 1
# 3         47.56108917      -122.38611809            3                 2
# 4         47.59229464      -122.30748656            4                 3
# ..                ...                ...          ...               ...
# 995       47.55529368      -122.38972980           21                 2
# 996       47.70179210      -122.34465537          153                 0
# 997       47.56350107      -122.28171391            4                 4
# 998       47.70858578      -122.32191838           38                 0
# 999       47.68606261      -122.31425377           91                 0
#
#      zip_code  township_id
# 0         NaN            0
# 1         NaN            1
# 2         NaN            1
# 3         NaN            2
# 4         NaN            3
# ..        ...          ...
# 995       NaN            2
# 996       NaN           12
# 997       NaN           22
# 998       NaN           12
# 999       NaN            8
#
# [1000 rows x 9 columns]

# %%
# write to sqlite db
conn = sqlite3.connect('seattledb.sqlite3')
df_emergencycall.to_sql('dashboard_emergencycall', conn, if_exists='replace', index=False)
df_township.to_sql('dashboard_township', conn, if_exists='replace', index=False)
df_responseunit.to_sql('dashboard_responseunit', conn, if_exists='replace', index=False)
df_category.to_sql('dashboard_category', conn, if_exists='replace', index=False)
df_responsetype.to_sql('dashboard_responsetype', conn, if_exists='replace', index=False)

conn.commit()
conn.close()
